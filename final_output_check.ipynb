# %%
import pandas as pd

df1 = pd.read_csv('C:/Github/EEG-Mouse/data/train.csv', header=None)
df2 = pd.read_csv('C:/Github/EEG-Mouse/outputs/1d_model/final/concatenated_train_final_data_epoch_final.csv', header=None)

# Check exact equality (values and shape)
are_equal = df1.equals(df2)

print("Files are equal:" if are_equal else "Files are different.")
# Out:
# Files are different.

# %%
df1.head()
# Out:
#          0           1          2           3           4           5     \
# 0   30.088278   58.298913  75.966152   71.572342   41.492319    3.738996
# 1 -121.407340 -100.747982 -65.330241  -38.441355  -35.750788  -56.006537
# 2  -28.355988  -31.862925 -16.072848    6.351046   28.004965   40.304392
# 3  -85.012211  -76.476292 -79.968394 -101.516080 -124.068800 -124.180187
# 4  -33.806979  -48.535948 -79.573954 -110.908244 -128.587110 -133.524734
#
#          6           7           8           9     ...        1270  \
# 0  -10.255864   22.190196   78.897725  109.698217  ...  111.674031
# 1  -82.028244  -97.005947 -105.138312 -123.529299  ...  -31.278507
# 2   26.985305  -14.892353  -57.970621  -66.476236  ...  -16.939070
# 3  -98.184534  -63.555797  -36.025803  -21.056813  ... -154.284862
# 4 -128.653265 -113.150259  -95.529259  -88.067007  ...    6.036766
#
#          1271        1272        1273        1274        1275        1276  \
# ...

# %%
df2.head()
# Out:
#          0           1         2           3           4           5     \
# 0   30.088278   58.298912  75.96615   71.572340   41.492317    3.738996
# 1 -121.407340 -100.747986 -65.33024  -38.441357  -35.750790  -56.006540
# 2  -28.355988  -31.862925 -16.07285    6.351046   28.004965   40.304394
# 3  -85.012215  -76.476295 -79.96839 -101.516080 -124.068800 -124.180190
# 4  -33.806980  -48.535950 -79.57395 -110.908240 -128.587110 -133.524730
#
#          6           7           8           9     ...       1270       1271  \
# 0  -10.255864   22.190195   78.897730  109.698220  ...  89.846200  67.239586
# 1  -82.028244  -97.005940 -105.138310 -123.529300  ... -87.540330 -89.984760
# 2   26.985306  -14.892353  -57.970620  -66.476234  ...  69.319275  55.746900
# 3  -98.184530  -63.555798  -36.025803  -21.056812  ... -40.318245 -16.208640
# 4 -128.653260 -113.150260  -95.529260  -88.067010  ...  -0.872234  23.065622
#
# ...
